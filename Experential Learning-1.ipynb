# %% [markdown]
# ### Name: Lahari Kasarla
# ### Class: CSE-2
# ### Reg. no: 1700229C203
# ### ADS - Experiential Learning-1 Submission

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('insurance.csv')
std = StandardScaler()

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### We will be using this dataset which contains data about how much various patients have paid as an insurance for their operations in a hospital.
#
# ####

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ### No null values present in the dataset.
# ####

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
maleno = len(data[data['sex']=='male'])
femaleno = len(data[data['sex']=='female'])
import matplotlib.pyplot as plt
import seaborn as sns
Gender = [maleno,femaleno]
my_labels = 'Male','Female'
plt.pie(Gender,labels=my_labels,autopct='%1.1f%%')
plt.title('Gender')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Males comprised 50.5% and Females comprised 49.5% of the dataset. Thus, it is a balanced dataset without any bias pertaining to gender.
#
# ####

# %%
smokers = len(data[data['smoker']=='yes'])
non_smokers = len(data[data['smoker']=='no'])
plt.figure
Smokers = [smokers,non_smokers]

my_labels = 'Yes','No'
plt.pie(Smokers,labels=my_labels,autopct='%1.0f%%')
plt.title('Smokers')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Smokers comprised 20% and Non-smokers comprised 80%.
#
# ####

# %%
sns.catplot(x="children", kind="count", palette="Reds_r", data=data, size = 6)
# Out:
# C:\Users\lahar\Anaconda3\Anaa\lib\site-packages\seaborn\categorical.py:3692: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### 560 people(majority) have no children, and very less people i.e 20 have 5 children.
#
# ####

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(data.corr(),cmap="Blues",annot=True)
plt.show()

# %% [markdown]
# ### We can see that no high correlations are found in the data. The highest correlation between two different variables(age & charges) is 0.3, and the lowest(children & bmi) being 0.013.
# ####

# %%
f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(data['charges'],bins=50,color='b',ax=ax)
ax.set_title('Distribution of insurance charges')
# Out:
# Text(0.5, 1.0, 'Distribution of insurance charges')

# %% [markdown]
# ### Most of the people have bought the insurance at lower prices than Rs.10000.
#
# ####

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of bmi")
ax = sns.distplot(data["bmi"], color = 'r')

# %% [markdown]
# ### From the above graph, we can understand that average bmi(body mass index) is 30.
#
# ####

# %%
sns.boxplot(data["age"]);
plt.show()

# %% [markdown]
# ### From the above graph, we can understand that average age is 39.
#
# ####

# %%
plt.figure(figsize=(10,10))
ax = sns.barplot(x='region', y='charges', hue='sex', data=data, palette='Reds_r')

# %% [markdown]
# ### In every region except Northwest, males have paid higher charges than females.
# ####

# %%
plt.figure(figsize=(10,10))
ax = sns.barplot(x = 'region', y = 'charges',
                 hue='smoker', data=data, palette='Reds_r')

# %% [markdown]
# ### As we can see in the graph above, smokers have paid really high charges as compared to non-smokers. It can be understood as smokers have a higher tendancy of having lesser immunity due to health concerns associated with smoking, and hence the higher charges to operate them.
# ####

# %%
charges = data['charges'].groupby(data.region).sum().sort_values(ascending = True)
f, ax = plt.subplots(1, 1, figsize=(8, 6))
ax = sns.barplot(charges.head(), charges.head().index, palette='Reds')

# %% [markdown]
# ### People of Southeastern region have paid more than other regions' people.
# ####

# %%
plt.figure(figsize=(10,10))
sns.violinplot(x='sex', y='charges',data=data)
plt.title('Violin plot of Charges vs sex')
# Out:
# Text(0.5, 1.0, 'Violin plot of Charges vs sex')

# %% [markdown]
# ### Both males and females have almost the same median value of charges i.e Rs.6000.
#
# ####

# %%
plt.figure(figsize=(10,10))
sns.violinplot(x='smoker', y='charges',data=data)
plt.title('Violin plot of Charges vs smoker');

# %% [markdown]
# ### Here, evidently the smokers and non-smokers have different median and other values too because there is a huge difference in their hospital charges as seen in the previous graphs.
#
#
# ####

# %%
f = plt.figure(figsize=(10,10))
sns.scatterplot(x='age',y='charges',data=data,palette='Reds_r',hue='smoker')
plt.title('Scatter plot of Charges vs age')
# Out:
# Text(0.5, 1.0, 'Scatter plot of Charges vs age')

# %% [markdown]
# ### Most of the smokers have paid an amount of Rs. 15000 - Rs.50000 for their charges. Whereas the majority of non-smokers have paid an amount ranging from Rs.1000 - Rs.15000.

# %%
f = plt.figure(figsize=(10,10))
sns.scatterplot(x='bmi',y='charges',data=data,palette='Blues',hue='smoker')
plt.title('Scatter plot of Charges vs bmi')
# Out:
# Text(0.5, 1.0, 'Scatter plot of Charges vs bmi')

# %% [markdown]
# ### Mostly, people with bmi range 20-40 have paid less than 15000 for their charges. Not everyone, but majority of them.
# ####

# %% [markdown]
# ## Let's conduct a hypothesis testing to check the hypothesis - Charges are highly different for smokers an nnon-smokers.

# %%
import numpy as np

# %%
df_cat = data.loc[:,["sex","children","smoker","region"]]

# %%
df_cat["smoker"].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
smokecharges = data[data["smoker"]=="yes"]["charges"]

# %%
nonsmokecharges = data[data["smoker"]=="no"]["charges"]

# %%
print(f"Mean of smoker charges: {np.mean(smokecharges)}")
print(f"Mean of non-smoker charges: {np.mean(nonsmokecharges)}")
# Out:
# Mean of smoker charges: 32050.23183153285
# Mean of non-smoker charges: 8434.268297856199

# %%
print(f"Std of smoker charges: {np.std(smokecharges)}")
print(f"Std of non-smoker charges: {np.std(nonsmokecharges)}")
# Out:
# Std of smoker charges: 11520.466706529429
# Std of non-smoker charges: 5990.964530287611

# %% [markdown]
# ### Null Hypothesis: Charges don't highly differ for smokers and non smokers.
# ### Alternative Hypothesis: Charges highly differ for smokers and non smokers.
# ### Significance Level Alpha = 0.05
#
#
# ####

# %%
from scipy.stats import ttest_ind
t_statistic,pval = ttest_ind(ppl_smoke_chrge,ppl_nosmoke_chrge)
print('P Value ',pval)
# Out:
# P Value  8.271435842177219e-283

# %% [markdown]
# ### As pval is very much less than significance level, we will reject null hypothesis.
# ### So, it can be concluded with proper evidence that hospital insurance charges highly differ for smokers and non smokers.
#
# ####

# %% [markdown]
# # My Contributions #
#
#
# #### Almost all insights have been collected by Kagglers, these were a few insights I gained:
# #### Males comprised 50.5% and Females comprised 49.5% of the dataset. Thus, it is a balanced dataset without any bias pertaining to gender.
# #### Smokers comprised 20% and Non-smokers comprised 80%.
# #### Most of the people have bought the insurance at lower prices than Rs.10000.
# #### Both males and females have almost the same median value of charges i.e Rs.6000.
# #### Here, evidently the smokers and non-smokers have different median in hospital charges because there is a huge difference in their hospital charges as seen in the previous graphs.
# #### Most of the smokers have paid an amount of Rs. 15000 - Rs.50000 for their charges. Whereas the majority of non-smokers have paid an amount ranging from Rs.1000 - Rs.15000.  Mostly, people with bmi range 20-40 have paid less than 15000 for their charges. Not everyone, but majority of them.

# %% [markdown]
# # References #
#
# ### https://www.kaggle.com/mariapushkareva/medical-insurance-cost-with-linear-regression
# ### https://www.kaggle.com/janiobachmann/patient-charges-clustering-and-regression
# ### https://www.kaggle.com/hely333/eda-regression
